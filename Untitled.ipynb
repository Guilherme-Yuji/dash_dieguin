# %%
import pandas as pd
import numpy as np
import datetime
import math

# %%
operation = pd.read_excel('Operations 03.26.24.xlsx')
orders = pd.read_excel('Opern Production Orders 03.26.24.xlsx')

# %%
operation = operation.rename(columns = {'Production Order Number':'PRODUCTION ORDER NO'})

# %%
df = orders.merge(operation, on = 'PRODUCTION ORDER NO')
qtd_process = df.groupby('PRODUCTION ORDER NO', as_index = False).agg({'Work Center' : pd.Series.nunique})
qtd_process.columns = ['PRODUCTION ORDER NO', 'PROCESS QT']
df = df.merge(qtd_process, on = 'PRODUCTION ORDER NO')
df['DELAY'] = (datetime.datetime.today() - df['PW DUE DATE']).dt.days
df.loc[df['DELAY'] < 0 , 'DELAY'] = 0

df_work = df.groupby('PRODUCTION ORDER NO', as_index=False).agg({'Work Center' : pd.Series.unique})
seed = np.random.RandomState(2024)
df_work['ACTUAL_WORK'] = df_work['Work Center'].apply(lambda x: seed.choice(x))

df = df.merge(df_work[['PRODUCTION ORDER NO','ACTUAL_WORK']], on = 'PRODUCTION ORDER NO')
df_group = df.groupby(['PRODUCTION ORDER NO','CUSTOMER NAME', 'SALES ORDER NO',"PW POST DATE",'PW DUE DATE','ACTUAL_WORK'], as_index= False)[['PROCESS QT','DELAY']].mean()

# %%
setores = df_group['ACTUAL_WORK'].value_counts().reset_index()

# %%
qtd_columns = math.ceil(df_group['ACTUAL_WORK'].nunique()/5)
setores['col'] = np.ceil((setores.index + 1)/qtd_columns) - 1
setores['col'] = ([0,1,2,3,4]*qtd_columns)[:setores.shape[0]]

# %%
setores
# Out:
#    ACTUAL_WORK  count  col
# 0      INSP-01     21    0
# 1      INSP-02     20    1
# 2      HEAT-01     15    2
# 3     MAZAK-04     12    3
# 4     GRIND-01     11    4
# 5     SRMAN-01     10    0
# 6       EDM-05     10    1
# 7     GRIND-06      9    2
# 8     GRIND-03      7    3
# 9     BOSTO-03      7    4
# 10    SRMAN-02      7    0
# 11    MAZAK-02      7    1
# 12    MAZAK-01      7    2
# 13    BOSTO-01      5    3
# 14    GRIND-02      4    4
# 15      EDM-01      4    0
# 16      EDM-04      3    1
# 17    MAZAK-03      3    2
# 18    GRIND-08      3    3
# 19    BOSTO-02      3    4
# 20   INDUCT-01      3    0
# 21   CHROME-01      2    1
# 22      EDM-02      2    2
# 23     HAAS-01      2    3
# 24    SRMAN-03      1    4
# 25    BOSTO-05      1    0
# 26     INSP-03      1    1
# 27     ENVL-04      1    2
# 28    GRIND-04      1    3
# 29    MAZAK-05      1    4
# 30      OUT-03      1    0
# 31     ENVL-05      1    1
# 32      ENG-01      1    2
# 33      OUT-04      1    3

# %%
df['DELAY'].hist()
# Out:
# <Axes: >

# %%
# Out:
#       PRODUCTION ORDER NO                                      CUSTOMER NAME  \
# 0                  193421                      Nittany Envelope Incorporated
# 1                  193421                      Nittany Envelope Incorporated
# 2                  193421                      Nittany Envelope Incorporated
# 3                  193421                      Nittany Envelope Incorporated
# 4                  193421                      Nittany Envelope Incorporated
# ...                   ...                                                ...
# 1593               189439  Duraco Specialty Tapes LLC - D/B/A  Essentra S...
# 1594               189439  Duraco Specialty Tapes LLC - D/B/A  Essentra S...
# 1595               189439  Duraco Specialty Tapes LLC - D/B/A  Essentra S...
# 1596               189439  Duraco Specialty Tapes LLC - D/B/A  Essentra S...
# 1597               189439  Duraco Specialty Tapes LLC - D/B/A  Essentra S...
#
#       SALES ORDER NO  PRODUCT NO  \
# 0             175270  SRE-510148
# 1             175270  SRE-510148
# 2             175270  SRE-510148
# 3             175270  SRE-510148
# 4             175270  SRE-510148
# ...              ...         ...
# 1593          171867   NW-203734
# 1594          171867   NW-203734
# 1595          171867   NW-203734
# 1596          171867   NW-203734
# 1597          171867   NW-203734
#
#                                     PRODUCT DESCRIPTION    DRAWING NO  \
# 0     Solid Die, Double on Shaft, 11/16 X 3-5/8, 1-1...  DWIN0F351242
# 1     Solid Die, Double on Shaft, 11/16 X 3-5/8, 1-1...  DWIN0F351242
# 2     Solid Die, Double on Shaft, 11/16 X 3-5/8, 1-1...  DWIN0F351242
# 3     Solid Die, Double on Shaft, 11/16 X 3-5/8, 1-1...  DWIN0F351242
# 4     Solid Die, Double on Shaft, 11/16 X 3-5/8, 1-1...  DWIN0F351242
# ...                                                 ...           ...
# 1593  19199 10" Rotary 81-1/8cp 0.222x0.315x0.033r+S...           NaN
# 1594  19199 10" Rotary 81-1/8cp 0.222x0.315x0.033r+S...           NaN
# 1595  19199 10" Rotary 81-1/8cp 0.222x0.315x0.033r+S...           NaN
# 1596  19199 10" Rotary 81-1/8cp 0.222x0.315x0.033r+S...           NaN
# 1597  19199 10" Rotary 81-1/8cp 0.222x0.315x0.033r+S...           NaN
#
#      PW POST DATE PW DUE DATE  Operation Number Work Center  PROCESS QT
# 0      2024-03-26  2024-03-28                10      ENG-01           9
# 1      2024-03-26  2024-03-28                20      ENG-04           9
# 2      2024-03-26  2024-03-28                30    MAZAK-01           9
# 3      2024-03-26  2024-03-28                40    BOSTO-01           9
# 4      2024-03-26  2024-03-28                45      EDM-05           9
# ...           ...         ...               ...         ...         ...
# 1593   2023-12-07  2023-12-19                60    GRIND-01          11
# 1594   2023-12-07  2023-12-19                64    BOSTO-02          11
# 1595   2023-12-07  2023-12-19                68    GRIND-04          11
# 1596   2023-12-07  2023-12-19                80    SHARP-03          11
# 1597   2023-12-07  2023-12-19                90     INSP-03          11
#
# [1598 rows x 11 columns]

# %%
#Pegando a quantidade em cada setor
df['Work Center'].value_counts()
# Out:
# Work Center
# INSP-01        175
# MAZAK-04       151
# INSP-02        116
# GRIND-01       116
# SRMAN-01       113
# EDM-05          97
# HEAT-01         92
# BOSTO-01        75
# MAZAK-01        71
# BOSTO-03        48
# MAZAK-03        46
# GRIND-06        42
# MAZAK-05        41
# GRIND-03        39
# MAZAK-02        39
# EDM-04          38
# SRMAN-02        38
# GRIND-04        31
# BOSTO-02        28
# GRIND-08        24
# RRMAN-04        22
# HAAS-01         17
# GRIND-02        16
# SRMAN-03        15
# OUT-04          15
# EDM-01          15
# EDM-02          13
# INDUCT-01        8
# CHROME-01        7
# ENG-04           6
# SRMAN-04         5
# ENG-01           4
# SHARP-03         3
# OUT-11           3
# BOSTO-05         3
# RRMAN-05         3
# INSP-03          3
# SRMAN-06         2
# ENVL-03          2
# ENVL-04          2
# OUT-03           2
# ENG-03           2
# BOSTO-04         2
# ENVL-02          1
# ENVL-06          1
# ENVL-05          1
# HAAS-02          1
# ENVL-01          1
# RRMAN-01         1
# RRFLYKNF-01      1
# ENVL-07          1
# Name: count, dtype: int64

# %%
df.loc[df['PRODUCTION ORDER NO'] == 193421]
# Out:
#    PRODUCTION ORDER NO                  CUSTOMER NAME  SALES ORDER NO  \
# 0               193421  Nittany Envelope Incorporated          175270
# 1               193421  Nittany Envelope Incorporated          175270
# 2               193421  Nittany Envelope Incorporated          175270
# 3               193421  Nittany Envelope Incorporated          175270
# 4               193421  Nittany Envelope Incorporated          175270
# 5               193421  Nittany Envelope Incorporated          175270
# 6               193421  Nittany Envelope Incorporated          175270
# 7               193421  Nittany Envelope Incorporated          175270
# 8               193421  Nittany Envelope Incorporated          175270
#
#    PRODUCT NO                                PRODUCT DESCRIPTION  \
# 0  SRE-510148  Solid Die, Double on Shaft, 11/16 X 3-5/8, 1-1...
# 1  SRE-510148  Solid Die, Double on Shaft, 11/16 X 3-5/8, 1-1...
# 2  SRE-510148  Solid Die, Double on Shaft, 11/16 X 3-5/8, 1-1...
# 3  SRE-510148  Solid Die, Double on Shaft, 11/16 X 3-5/8, 1-1...
# 4  SRE-510148  Solid Die, Double on Shaft, 11/16 X 3-5/8, 1-1...
# 5  SRE-510148  Solid Die, Double on Shaft, 11/16 X 3-5/8, 1-1...
# 6  SRE-510148  Solid Die, Double on Shaft, 11/16 X 3-5/8, 1-1...
# 7  SRE-510148  Solid Die, Double on Shaft, 11/16 X 3-5/8, 1-1...
# 8  SRE-510148  Solid Die, Double on Shaft, 11/16 X 3-5/8, 1-1...
#
#      DRAWING NO PW POST DATE PW DUE DATE  Operation Number Work Center
# 0  DWIN0F351242   2024-03-26  2024-03-28                10      ENG-01
# 1  DWIN0F351242   2024-03-26  2024-03-28                20      ENG-04
# 2  DWIN0F351242   2024-03-26  2024-03-28                30    MAZAK-01
# 3  DWIN0F351242   2024-03-26  2024-03-28                40    BOSTO-01
# 4  DWIN0F351242   2024-03-26  2024-03-28                45      EDM-05
# 5  DWIN0F351242   2024-03-26  2024-03-28                50     HEAT-01
# 6  DWIN0F351242   2024-03-26  2024-03-28                60    GRIND-01
# 7  DWIN0F351242   2024-03-26  2024-03-28                70    RRMAN-05
# 8  DWIN0F351242   2024-03-26  2024-03-28                80     INSP-02
